# %%
"""
MSVGDd method in dual space
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MSVGDd  --task dirichletUniform --particle_num 256 --lr 3.0 --alpha 0.02 --knType rbf --bwType med  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MSVGDd_lr[3.0e+00]al[2.0e-02]kn[rbf,med]s[0]
# 2023-03-13 16:57:30,109 MSVGDd INFO:
#  - algorithm: MSVGDd
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 3.0
#  - alpha: 0.02
#  - knType: rbf
#  - bwType: med
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 16:57:35,869 MSVGDd INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 16:57:36,690 MSVGDd INFO: count: 100, w2_primal: 3.22e-02, w2_dual: 5.01e-01
# 2023-03-13 16:57:37,447 MSVGDd INFO: count: 200, w2_primal: 3.15e-02, w2_dual: 4.37e-01
# 2023-03-13 16:57:38,198 MSVGDd INFO: count: 300, w2_primal: 3.11e-02, w2_dual: 4.17e-01
# ...

# %%
"""
MSVGDp method
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MSVGDp  --task dirichletUniform --particle_num 256 --lr 2.0 --alpha 0.02 --knType rbf --bwType med  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MSVGDp_lr[2.0e+00]al[2.0e-02]kn[rbf,med]s[0]
# 2023-03-13 16:58:16,795 MSVGDp INFO:
#  - algorithm: MSVGDp
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 2.0
#  - alpha: 0.02
#  - knType: rbf
#  - bwType: med
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 16:58:22,576 MSVGDp INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 16:58:23,414 MSVGDp INFO: count: 100, w2_primal: 3.03e-02, w2_dual: 8.48e-01
# 2023-03-13 16:58:24,196 MSVGDp INFO: count: 200, w2_primal: 2.91e-02, w2_dual: 7.74e-01
# 2023-03-13 16:58:24,975 MSVGDp INFO: count: 300, w2_primal: 2.87e-02, w2_dual: 7.38e-01
# ...

# %%
"""
MedBLOBd method in dual space
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MedBLOBd  --task dirichletUniform --particle_num 256 --lr 0.02 --alpha 0.02 --knType rbf --bwType nei  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MedBLOBd_lr[2.0e-02]al[2.0e-02]kn[rbf,nei]s[0]
# 2023-03-13 16:59:04,340 MedBLOBd INFO:
#  - algorithm: MedBLOBd
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 0.02
#  - alpha: 0.02
#  - knType: rbf
#  - bwType: nei
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 16:59:10,133 MedBLOBd INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 16:59:10,977 MedBLOBd INFO: count: 100, w2_primal: 3.96e-02, w2_dual: 8.84e-01
# 2023-03-13 16:59:11,747 MedBLOBd INFO: count: 200, w2_primal: 3.01e-02, w2_dual: 6.61e-01
# 2023-03-13 16:59:12,524 MedBLOBd INFO: count: 300, w2_primal: 2.87e-02, w2_dual: 5.79e-01
# ...

# %%
"""
MedBLOBdCA method in dual space
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MedBLOBdCA  --task dirichletUniform --particle_num 256 --lr 0.02 --alpha 0.05 --knType rbf --bwType nei  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MedBLOBdCA_lr[2.0e-02]al[5.0e-02]kn[rbf,nei]s[0]
# 2023-03-13 16:59:50,958 MedBLOBdCA INFO:
#  - algorithm: MedBLOBdCA
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 0.02
#  - alpha: 0.05
#  - knType: rbf
#  - bwType: nei
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 16:59:56,658 MedBLOBdCA INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 16:59:57,532 MedBLOBdCA INFO: count: 100, w2_primal: 3.91e-02, w2_dual: 8.78e-01
# 2023-03-13 16:59:58,343 MedBLOBdCA INFO: count: 200, w2_primal: 2.97e-02, w2_dual: 6.59e-01
# 2023-03-13 16:59:59,153 MedBLOBdCA INFO: count: 300, w2_primal: 2.83e-02, w2_dual: 5.78e-01
# ...

# %%
"""
MedBLOBp method
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MedBLOBp  --task dirichletUniform --particle_num 256 --lr 0.003 --alpha 0.01 --knType rbf --bwType nei  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MedBLOBp_lr[3.0e-03]al[1.0e-02]kn[rbf,nei]s[0]
# 2023-03-13 17:00:39,547 MedBLOBp INFO:
#  - algorithm: MedBLOBp
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 0.003
#  - alpha: 0.01
#  - knType: rbf
#  - bwType: nei
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 17:00:45,320 MedBLOBp INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 17:00:46,221 MedBLOBp INFO: count: 100, w2_primal: 1.18e-01, w2_dual: 1.60e+00
# 2023-03-13 17:00:47,075 MedBLOBp INFO: count: 200, w2_primal: 7.76e-02, w2_dual: 1.33e+00
# 2023-03-13 17:00:47,892 MedBLOBp INFO: count: 300, w2_primal: 5.77e-02, w2_dual: 1.16e+00
# ...

# %%
"""
MedBLOBpCA method
"""
import os
command = 'python main.py --config_path ./configs/default.yaml --over_writen --algorithm MedBLOBpCA  --task dirichletUniform --particle_num 256 --lr 0.003 --alpha 0.05 --knType rbf --bwType nei  --bwVal 0.1 --max_iter 5000 --max_time 120 --optim sgd --optim_rho 0.9 --reference_num 2000 --eval_interval 100 --device cuda:3 --result_dir results --seed 0'
os.system(command)
# Out:
# - clear files in results/MedBLOBpCA_lr[3.0e-03]al[5.0e-02]kn[rbf,nei]s[0]
# 2023-03-13 17:01:28,214 MedBLOBpCA INFO:
#  - algorithm: MedBLOBpCA
#  - task: dirichletUniform
#  - particle_num: 256
#  - lr: 0.003
#  - alpha: 0.05
#  - knType: rbf
#  - bwType: nei
#  - bwVal: 0.1
#  - max_iter: 5000
#  - time_mode: False
#  - max_time: 120
#  - optim: sgd
#  - optim_rho: 0.9
#  - reference_num: 2000
#  - eval_interval: 100
#  - device: cuda:3
#  - result_dir: results
#  - time_as_dir: False
#  - seed: 0
#  - config_path: ./configs/default.yaml
#  - over_writen: True
#  - n_eigen_threshold: 0.98
#
# 2023-03-13 17:01:33,916 MedBLOBpCA INFO: count: 0, w2_primal: 2.44e-01, w2_dual: 2.10e+00
# 2023-03-13 17:01:34,863 MedBLOBpCA INFO: count: 100, w2_primal: 1.18e-01, w2_dual: 1.59e+00
# 2023-03-13 17:01:35,770 MedBLOBpCA INFO: count: 200, w2_primal: 7.71e-02, w2_dual: 1.33e+00
# 2023-03-13 17:01:36,627 MedBLOBpCA INFO: count: 300, w2_primal: 5.70e-02, w2_dual: 1.16e+00
# ...
